# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time

# %%
scope = 'user-top-read user-library-read'
sp = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(scope=scope))

# %%
sp.user_playlists(sp.current_user()['id'])
# Out:
# {'href': 'https://api.spotify.com/v1/users/cikolatamanyagi/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'A playlist to boost yourself while coding, full of songs by one of the greatest rock bands: Muse',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/642tdkNMhvcuvzkUplEpnm'},
#    'href': 'https://api.spotify.com/v1/playlists/642tdkNMhvcuvzkUplEpnm',
#    'id': '642tdkNMhvcuvzkUplEpnm',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb3a9181af688383e734a5eeb8',
#      'width': None}],
#    'name': 'play.muse();',
#    'owner': {'display_name': 'İdil Sülo',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/cikolatamanyagi'},
#     'href': 'https://api.spotify.com/v1/users/cikolatamanyagi',
#     'id': 'cikolatamanyagi',
#     'type': 'user',
#     'uri': 'spotify:user:cikolatamanyagi'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzcsMDhiZmVmNWY0ZDg3NGM1ZmZhOGY1MmExOTE2MjEyM2M1YzAxYzViMA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/642tdkNMhvcuvzkUplEpnm/tracks',
#     'total': 23},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:642tdkNMhvcuvzkUplEpnm'},
#   {'collaborative': False,
#    'description': 'something common in the universe, but rare on earth',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7c8PECszoivCyj45rHyqXp'},
#    'href': 'https://api.spotify.com/v1/playlists/7c8PECszoivCyj45rHyqXp',
#    'id': '7c8PECszoivCyj45rHyqXp',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb5cb607241e298dccce0f6d71',
#      'width': None}],
#    'name': 'rare',
#    'owner': {'display_name': 'İdil Sülo',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/cikolatamanyagi'},
#     'href': 'https://api.spotify.com/v1/users/cikolatamanyagi',
#     'id': 'cikolatamanyagi',
#     'type': 'user',
#     'uri': 'spotify:user:cikolatamanyagi'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDUsM2FlNzZkZDA3ZTUzOGFkOWI1MWVjMmVjMWVkMjk5NzE0MTgxYzg0Mw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7c8PECszoivCyj45rHyqXp/tracks',
#     'total': 25},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7c8PECszoivCyj45rHyqXp'},
#   {'collaborative': False,
#    'description': 'unsucessful termination',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3SfHln0BLyC6cke3CK4p1I'},
#    'href': 'https://api.spotify.com/v1/playlists/3SfHln0BLyC6cke3CK4p1I',
#    'id': '3SfHln0BLyC6cke3CK4p1I',
#    'images': [{'height': 300,
#      'url': 'https://i.scdn.co/image/ab67706c0000da84b18976ddad9828a2fe29f768',
#      'width': 300}],
#    'name': 'exit(1);',
#    'owner': {'display_name': 'İdil Sülo',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/cikolatamanyagi'},
#     'href': 'https://api.spotify.com/v1/users/cikolatamanyagi',
#     'id': 'cikolatamanyagi',
#     'type': 'user',
#     'uri': 'spotify:user:cikolatamanyagi'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTUsNDhkYTlkZjQzOTUyYWVhYzI4ZmJmN2U4YjUwMTAzMmIwYTU1ODVmMw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3SfHln0BLyC6cke3CK4p1I/tracks',
#     'total': 7},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3SfHln0BLyC6cke3CK4p1I'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7tfB4IHcNZuRMtr1EJbBo8'},
#    'href': 'https://api.spotify.com/v1/playlists/7tfB4IHcNZuRMtr1EJbBo8',
#    'id': '7tfB4IHcNZuRMtr1EJbBo8',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb931151359d2d87bd97d26c46',
#      'width': None}],
#    'name': 'Pearl Jam List',
#    'owner': {'display_name': 'İdil Sülo',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/cikolatamanyagi'},
#     'href': 'https://api.spotify.com/v1/users/cikolatamanyagi',
#     'id': 'cikolatamanyagi',
#     'type': 'user',
#     'uri': 'spotify:user:cikolatamanyagi'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDEsNGFjNjM2YzA1Mjk3YjNkMTRmMWZiZmM3MTBjNjM0ODgzNWVlNzM1Yw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7tfB4IHcNZuRMtr1EJbBo8/tracks',
#     'total': 33},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7tfB4IHcNZuRMtr1EJbBo8'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 4}

# %%
results = sp.current_user_top_artists(time_range='short_term', limit=50)

# %%
all_genres = [genre for r in results['items'] for genre in r['genres'] ]

# %%
all_genres
# Out:
# ['french indie pop',
#  'french indietronica',
#  'french synthpop',
#  'indie soul',
#  'new french touch',
#  'downtempo',
#  'indie soul',
#  'indietronica',
#  'shimmer pop',
#  'french indie pop',
#  'french indietronica',
#  'new french touch',
#  'electronica',
#  'ethnotronica',
#  'organic electronic',
#  'organic house',
#  'electronica',
#  'indie soul',
#  'vapor soul',
#  'electronica',
#  'future garage',
#  'indie soul',
#  'electronica',
#  'french indietronica',
#  'indie soul',
#  'microhouse',
#  'minimal techno',
#  'french indie pop',
#  'french indietronica',
#  'indie soul',
#  'new french touch',
#  'tropical house',
#  'alternative dance',
#  'electronica',
#  'indie soul',
#  'new rave',
#  'nu disco',
#  'alternative dance',
#  'electronica',
#  'folktronica',
#  'indie soul',
#  'intelligent dance music',
#  'new rave',
#  'deep disco house',
#  'deep euro house',
#  'electronica',
#  'hamburg electronic',
#  'microhouse',
#  'minimal techno',
#  'organic electronic',
#  'organic house',
#  'tech house',
#  'alternative dance',
#  'deep disco house',
#  'deep house',
#  'electronica',
#  'float house',
#  'indie soul',
#  'microhouse',
#  'nu disco',
#  'spanish electronic',
#  'french indie pop',
#  'french indietronica',
#  'indie soul',
#  'new french touch',
#  'rennes indie',
#  'indie folk',
#  'vapor soul',
#  'alternative dance',
#  'chillwave',
#  'electronica',
#  'electropop',
#  'folktronica',
#  'indie rock',
#  'indie soul',
#  'indietronica',
#  'intelligent dance music',
#  'new rave',
#  'deep house',
#  'electronica',
#  'indie jazz',
#  'indie soul',
#  'ninja',
#  'nu jazz',
#  'soul',
#  'south african alternative',
#  'alternative dance',
#  'deep house',
#  'disco',
#  'disco house',
#  'electronica',
#  'filter house',
#  'indie soul',
#  'nu disco',
#  'vocal house',
#  'downtempo',
#  'electronica',
#  'canadian contemporary r&b',
#  'indie soul',
#  'vapor soul',
#  'alternative dance',
#  'alternative r&b',
#  'art pop',
#  'chillwave',
#  'downtempo',
#  'electronica',
#  'electropop',
#  'escape room',
#  'gothenburg indie',
#  'indie soul',
#  'indietronica',
#  'new rave',
#  'swedish electropop',
#  'swedish synthpop',
#  'trip hop',
#  'deep house',
#  'electronica',
#  'float house',
#  'indie jazz',
#  'indie soul',
#  'soul',
#  'swedish electronic',
#  'swedish house',
#  'swedish synthpop',
#  'auckland indie',
#  'electronica',
#  'indie soul',
#  'nu disco',
#  'vapor soul']

# %%
from collections import Counter
top_genres = Counter(all_genres)
top_genres = {key : value for key, value in sorted(top_genres.items(), key=lambda k: k[1], reverse=True)}
top_genres
# Out:
# {'indie soul': 17,
#  'electronica': 15,
#  'alternative dance': 6,
#  'french indietronica': 5,
#  'french indie pop': 4,
#  'new french touch': 4,
#  'vapor soul': 4,
#  'new rave': 4,
#  'nu disco': 4,
#  'deep house': 4,
#  'downtempo': 3,
#  'indietronica': 3,
#  'microhouse': 3,
#  'organic electronic': 2,
#  'organic house': 2,
#  'minimal techno': 2,
#  'folktronica': 2,
#  'intelligent dance music': 2,
#  'deep disco house': 2,
#  'float house': 2,
#  'chillwave': 2,
#  'electropop': 2,
#  'indie jazz': 2,
#  'soul': 2,
#  'swedish synthpop': 2,
#  'french synthpop': 1,
#  'shimmer pop': 1,
#  'ethnotronica': 1,
#  'future garage': 1,
#  'tropical house': 1,
#  'deep euro house': 1,
#  'hamburg electronic': 1,
#  'tech house': 1,
#  'spanish electronic': 1,
#  'rennes indie': 1,
#  'indie folk': 1,
#  'indie rock': 1,
#  'ninja': 1,
#  'nu jazz': 1,
#  'south african alternative': 1,
#  'disco': 1,
#  'disco house': 1,
#  'filter house': 1,
#  'vocal house': 1,
#  'canadian contemporary r&b': 1,
#  'alternative r&b': 1,
#  'art pop': 1,
#  'escape room': 1,
#  'gothenburg indie': 1,
#  'swedish electropop': 1,
#  'trip hop': 1,
#  'swedish electronic': 1,
#  'swedish house': 1,
#  'auckland indie': 1}

# %%
results
# Out:
# {'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4PwlsrN0t5mLN0C827cbEU'},
#    'followers': {'href': None, 'total': 188425},
#    'genres': ['french indie pop',
#     'french indietronica',
#     'french synthpop',
#     'indie soul',
#     'new french touch'],
#    'href': 'https://api.spotify.com/v1/artists/4PwlsrN0t5mLN0C827cbEU',
#    'id': '4PwlsrN0t5mLN0C827cbEU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/d4530a34df824be0f30b258d3e631620d0ec5097',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/796859ecc50c28a5ac7d74d13df7f1064251c458',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/c9fedeade4a924118d4f2cc61aa9e19fcff70db8',
#      'width': 160}],
#    'name': "L'Impératrice",
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:4PwlsrN0t5mLN0C827cbEU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2AcUPzkVWo81vumdzeLLRN'},
#    'followers': {'href': None, 'total': 457674},
#    'genres': ['downtempo', 'indie soul', 'indietronica', 'shimmer pop'],
#    'href': 'https://api.spotify.com/v1/artists/2AcUPzkVWo81vumdzeLLRN',
#    'id': '2AcUPzkVWo81vumdzeLLRN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/10bd370af9c0952279751e6d5a185125ca9d2a4b',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ba9355472169e4b7c99146ac0128307854712c12',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/05bdbd65e67a7069ba5a89ad8bdb82cf15bc3178',
#      'width': 160}],
#    'name': 'Rhye',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:2AcUPzkVWo81vumdzeLLRN'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1FTFy5sAOlZpN6GY6s9VLh'},
#    'followers': {'href': None, 'total': 18192},
#    'genres': ['french indie pop', 'french indietronica', 'new french touch'],
#    'href': 'https://api.spotify.com/v1/artists/1FTFy5sAOlZpN6GY6s9VLh',
#    'id': '1FTFy5sAOlZpN6GY6s9VLh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/7f80284ddf20e6600f08160abf3a8fd332bc6db8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/f366df8b4d576edf4dfd182f23a8406ee6b85c8c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/5c8cf3e8bebd9c11a3f3f10d7e8189f743638b41',
#      'width': 160}],
#    'name': 'Fellini Félin',
#    'popularity': 45,
#    'type': 'artist',
#    'uri': 'spotify:artist:1FTFy5sAOlZpN6GY6s9VLh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3YHAA3Ngue65DFIGVi0nqX'},
#    'followers': {'href': None, 'total': 1612},
#    'genres': [],
#    'href': 'https://api.spotify.com/v1/artists/3YHAA3Ngue65DFIGVi0nqX',
#    'id': '3YHAA3Ngue65DFIGVi0nqX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/990ed5c18b37cf38a782ebd1d0f11478f2c214d4',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/31016a3a0734a0cbd8aa381773619a6505c1f683',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/10afd7ae40184c41244920b88744fb05b4601213',
#      'width': 160}],
#    'name': 'Nahre Sol',
#    'popularity': 30,
#    'type': 'artist',
#    'uri': 'spotify:artist:3YHAA3Ngue65DFIGVi0nqX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lK8O3kyFThiTmgowQZGOH'},
#    'followers': {'href': None, 'total': 59844},
#    'genres': ['electronica',
#     'ethnotronica',
#     'organic electronic',
#     'organic house'],
#    'href': 'https://api.spotify.com/v1/artists/6lK8O3kyFThiTmgowQZGOH',
#    'id': '6lK8O3kyFThiTmgowQZGOH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/c4faf3838975ec5a09e8ecf0c6d1645beeb2b1ae',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/c1f8541166570e58734a53c7f486106dd4f3db72',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/c0c5ed0e034cb79b3d712cbb92382ff8f55f9026',
#      'width': 160}],
#    'name': 'Kerala Dust',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:6lK8O3kyFThiTmgowQZGOH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EnbnmqrrvApHJs6FMvYik'},
#    'followers': {'href': None, 'total': 107734},
#    'genres': ['electronica', 'indie soul', 'vapor soul'],
#    'href': 'https://api.spotify.com/v1/artists/3EnbnmqrrvApHJs6FMvYik',
#    'id': '3EnbnmqrrvApHJs6FMvYik',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/10c5079e0769a271489f94b874c0b94be979c1a2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/0bb02035323da8c145eea61e33972f6dec1436eb',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/e7f8092d3b29d9266e931a9edeb70b83ee0cbacd',
#      'width': 160}],
#    'name': 'Elder Island',
#    'popularity': 62,
#    'type': 'artist',
#    'uri': 'spotify:artist:3EnbnmqrrvApHJs6FMvYik'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7zrkALJ9ayRjzysp4QYoEg'},
#    'followers': {'href': None, 'total': 222825},
#    'genres': ['electronica', 'future garage', 'indie soul'],
#    'href': 'https://api.spotify.com/v1/artists/7zrkALJ9ayRjzysp4QYoEg',
#    'id': '7zrkALJ9ayRjzysp4QYoEg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1294a548ccadf00500f3524e7fa64434cf2fa6f5',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/38bea254aa0f766edc813d6f08261d5fdef8cafa',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/d2f6e76efff9f24525629b68585680c8006cc61e',
#      'width': 160}],
#    'name': 'Maribou State',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:7zrkALJ9ayRjzysp4QYoEg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/12tZvy2xFpWSkuJ3FsfisZ'},
#    'followers': {'href': None, 'total': 112118},
#    'genres': ['electronica',
#     'french indietronica',
#     'indie soul',
#     'microhouse',
#     'minimal techno'],
#    'href': 'https://api.spotify.com/v1/artists/12tZvy2xFpWSkuJ3FsfisZ',
#    'id': '12tZvy2xFpWSkuJ3FsfisZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/8e91f3979bdd5fb67cb217eff91c53c03bd63622',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/2e0534b5c971db403e0fa6c95deae6ffb3cffa36',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/6a939c9a7ec4967ce4955f10e2dbd1e1775c4481',
#      'width': 160}],
#    'name': 'Weval',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:12tZvy2xFpWSkuJ3FsfisZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/41Ue54Vb6iWx2dcdRCM6oH'},
#    'followers': {'href': None, 'total': 69202},
#    'genres': ['french indie pop',
#     'french indietronica',
#     'indie soul',
#     'new french touch',
#     'tropical house'],
#    'href': 'https://api.spotify.com/v1/artists/41Ue54Vb6iWx2dcdRCM6oH',
#    'id': '41Ue54Vb6iWx2dcdRCM6oH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/2ffdf1e6d9771861ff5d228c5823858d1d7368a2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/42ff476ff72947e8536ae1d325732862034aaa67',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ccc7e12cfe730d43614b621b561d0a0b9def6f35',
#      'width': 160}],
#    'name': 'Kazy Lambist',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:41Ue54Vb6iWx2dcdRCM6oH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/380fnmlGnkyueBMqGWx2k5'},
#    'followers': {'href': None, 'total': 77156},
#    'genres': ['alternative dance',
#     'electronica',
#     'indie soul',
#     'new rave',
#     'nu disco'],
#    'href': 'https://api.spotify.com/v1/artists/380fnmlGnkyueBMqGWx2k5',
#    'id': '380fnmlGnkyueBMqGWx2k5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1df89e5c30c9cbd9432628b916bca4fa875f9232',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/dabfa702397499ae40d5701815180c6a4fd4b03c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/472fc5c06c24269a6dc0cf41b37095927a52c39c',
#      'width': 160}],
#    'name': 'Joe Goddard',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:380fnmlGnkyueBMqGWx2k5'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#    'followers': {'href': None, 'total': 473244},
#    'genres': ['alternative dance',
#     'electronica',
#     'folktronica',
#     'indie soul',
#     'intelligent dance music',
#     'new rave'],
#    'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#    'id': '7Eu1txygG6nJttLHbZdQOh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/f96458025a0640bf1d3c8f764a42ec21d4db1eae',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/4547d5656309079fdfc73bef86a3c327cd59a3ea',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/e512f91d540d864906d36a850ecb9ad5d562d262',
#      'width': 160}],
#    'name': 'Four Tet',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cS5EoXVqz7aON00AkVBBA'},
#    'followers': {'href': None, 'total': 158613},
#    'genres': ['deep disco house',
#     'deep euro house',
#     'electronica',
#     'hamburg electronic',
#     'microhouse',
#     'minimal techno',
#     'organic electronic',
#     'organic house',
#     'tech house'],
#    'href': 'https://api.spotify.com/v1/artists/1cS5EoXVqz7aON00AkVBBA',
#    'id': '1cS5EoXVqz7aON00AkVBBA',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/8c2ada6ac1cb416ee3318453bf82480ab1e30fee',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/558316d72dc72db7ae2e7fae5f0962b921a018ac',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/09e51eca579a25fa5c6dbc28cb28ae68ed550c1e',
#      'width': 160}],
#    'name': 'DAVID AUGUST',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:1cS5EoXVqz7aON00AkVBBA'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/49mZfy9v5oNXAxp8FadWwI'},
#    'followers': {'href': None, 'total': 47148},
#    'genres': ['alternative dance',
#     'deep disco house',
#     'deep house',
#     'electronica',
#     'float house',
#     'indie soul',
#     'microhouse',
#     'nu disco',
#     'spanish electronic'],
#    'href': 'https://api.spotify.com/v1/artists/49mZfy9v5oNXAxp8FadWwI',
#    'id': '49mZfy9v5oNXAxp8FadWwI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1addc57bc6abb3abdb2b4128732c5ba2efecc20c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/2e368f8d5b3067b3e4bb1f56369e6864bf043691',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/db0a04f76e923c453b1bce476bb2f56f19137853',
#      'width': 160}],
#    'name': 'Pional',
#    'popularity': 47,
#    'type': 'artist',
#    'uri': 'spotify:artist:49mZfy9v5oNXAxp8FadWwI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1T2WeXEi0XlZiPpjjDAY0L'},
#    'followers': {'href': None, 'total': 123276},
#    'genres': ['french indie pop',
#     'french indietronica',
#     'indie soul',
#     'new french touch',
#     'rennes indie'],
#    'href': 'https://api.spotify.com/v1/artists/1T2WeXEi0XlZiPpjjDAY0L',
#    'id': '1T2WeXEi0XlZiPpjjDAY0L',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/b759eca20d09fb53cfbc532fbcaa4ef3f21c53bc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/7b7e2ff738b168a54706cdedf3f93014b8438e2d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/14a45f0bf1d82b5f57adc277a61e8d6f354f8c3a',
#      'width': 160}],
#    'name': 'Her',
#    'popularity': 56,
#    'type': 'artist',
#    'uri': 'spotify:artist:1T2WeXEi0XlZiPpjjDAY0L'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#    'followers': {'href': None, 'total': 309082},
#    'genres': ['indie folk', 'vapor soul'],
#    'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#    'id': '2KjAo6wVc9d2WcxdxSArpV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/69d060dade4be866821540883256e7c42ea816ca',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/5b23dc747a8538699e99d0bcc92286313179d330',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/972cb7c24e9a203a72e25bed7fd90675d68426e9',
#      'width': 160}],
#    'name': 'RY X',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#    'followers': {'href': None, 'total': 502796},
#    'genres': ['alternative dance',
#     'chillwave',
#     'electronica',
#     'electropop',
#     'folktronica',
#     'indie rock',
#     'indie soul',
#     'indietronica',
#     'intelligent dance music',
#     'new rave'],
#    'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#    'id': '4aEnNH9PuU1HF3TsZTru54',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1a2fc54c4edb1b614458d213c4f9b8b280f091cd',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/a0ccbf89bb9accbeace5c08044606cac288bbbb7',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/df0a17ba43b15b79b35bac1bda7e632371060afe',
#      'width': 160}],
#    'name': 'Caribou',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6d1HqiWNEKV9zFqQM9WeYo'},
#    'followers': {'href': None, 'total': 106311},
#    'genres': ['deep house',
#     'electronica',
#     'indie jazz',
#     'indie soul',
#     'ninja',
#     'nu jazz',
#     'soul',
#     'south african alternative'],
#    'href': 'https://api.spotify.com/v1/artists/6d1HqiWNEKV9zFqQM9WeYo',
#    'id': '6d1HqiWNEKV9zFqQM9WeYo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/25786db874ed0b674d5a1e9c1b0d193eaaa5d9ec',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/99acafe9a7093e8067b0d0d861a89ab70b363068',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/5f0d3f05f499a8e18668a32aef2a222d7a00184a',
#      'width': 160}],
#    'name': 'Romare',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:6d1HqiWNEKV9zFqQM9WeYo'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jOz2B9qeID4dLP1o8bFGf'},
#    'followers': {'href': None, 'total': 80170},
#    'genres': ['alternative dance',
#     'deep house',
#     'disco',
#     'disco house',
#     'electronica',
#     'filter house',
#     'indie soul',
#     'nu disco',
#     'vocal house'],
#    'href': 'https://api.spotify.com/v1/artists/6jOz2B9qeID4dLP1o8bFGf',
#    'id': '6jOz2B9qeID4dLP1o8bFGf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/8d8a829f7257e1121f7c9c56cda6f6d9f9db8948',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/542e7767dae504226c4ccaad2fb6ba9064081264',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/45a73ba299f6a42aa5b00029fde367bf62b404ad',
#      'width': 160}],
#    'name': 'Crazy P',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:6jOz2B9qeID4dLP1o8bFGf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2933wDUojoQmvqSdTAE5NB'},
#    'followers': {'href': None, 'total': 160312},
#    'genres': ['downtempo', 'electronica'],
#    'href': 'https://api.spotify.com/v1/artists/2933wDUojoQmvqSdTAE5NB',
#    'id': '2933wDUojoQmvqSdTAE5NB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/6c442802f177c6616e1775eec988c6561d4ba505',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/b32e68c8e2dca204daabd93a9d677e5ec65df4c2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/e6bb2256ecca7f5e6e6e06365aaad59876b2bbbd',
#      'width': 160}],
#    'name': 'DARKSIDE',
#    'popularity': 49,
#    'type': 'artist',
#    'uri': 'spotify:artist:2933wDUojoQmvqSdTAE5NB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/63vaeIIBKIe9zT91EORVbr'},
#    'followers': {'href': None, 'total': 73711},
#    'genres': ['canadian contemporary r&b', 'indie soul', 'vapor soul'],
#    'href': 'https://api.spotify.com/v1/artists/63vaeIIBKIe9zT91EORVbr',
#    'id': '63vaeIIBKIe9zT91EORVbr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/80cd4920d6be5fd32aa562b31e535e53d303b832',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/4ac6b97f0510518d9a8df49fd6288077536dbb3f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/1c632840bce2e73f4fbf652df7d453a1f27546b6',
#      'width': 160}],
#    'name': 'MorMor',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:63vaeIIBKIe9zT91EORVbr'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Tyzp9KzpiZ04DABQoedps'},
#    'followers': {'href': None, 'total': 533491},
#    'genres': ['alternative dance',
#     'alternative r&b',
#     'art pop',
#     'chillwave',
#     'downtempo',
#     'electronica',
#     'electropop',
#     'escape room',
#     'gothenburg indie',
#     'indie soul',
#     'indietronica',
#     'new rave',
#     'swedish electropop',
#     'swedish synthpop',
#     'trip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6Tyzp9KzpiZ04DABQoedps',
#    'id': '6Tyzp9KzpiZ04DABQoedps',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/2ab99177dac7d5f67c3596f9c941c8ee834de005',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/51ac7df0154f483d6434505b8e092512222a1f44',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/adfdfa7967b6ca4f5580831a2457778c69047a15',
#      'width': 160}],
#    'name': 'Little Dragon',
#    'popularity': 67,
#    'type': 'artist',
#    'uri': 'spotify:artist:6Tyzp9KzpiZ04DABQoedps'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Yae9Ia1nq6JLLojBzwN1r'},
#    'followers': {'href': None, 'total': 76985},
#    'genres': ['deep house',
#     'electronica',
#     'float house',
#     'indie jazz',
#     'indie soul',
#     'soul',
#     'swedish electronic',
#     'swedish house',
#     'swedish synthpop'],
#    'href': 'https://api.spotify.com/v1/artists/6Yae9Ia1nq6JLLojBzwN1r',
#    'id': '6Yae9Ia1nq6JLLojBzwN1r',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/dcf6166c631fa73d312cf015d791b2ac399b5c63',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/fa19641d4c10a663eb13b55c205ab2554834a1d3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/2ecb016f618e11271aab02d7eea5235cf8a8a2df',
#      'width': 160}],
#    'name': 'HNNY',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:6Yae9Ia1nq6JLLojBzwN1r'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7b04D0yLktCUpvxQBhmG7R'},
#    'followers': {'href': None, 'total': 89363},
#    'genres': ['auckland indie',
#     'electronica',
#     'indie soul',
#     'nu disco',
#     'vapor soul'],
#    'href': 'https://api.spotify.com/v1/artists/7b04D0yLktCUpvxQBhmG7R',
#    'id': '7b04D0yLktCUpvxQBhmG7R',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ca08311b12638f22b9dc06fd34848fff1a744952',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/84d3e52371f514c6a502b03845b0f9ca169a63f1',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/f50a6185537d049c8fa339fce8b586cd6cde4fce',
#      'width': 160}],
#    'name': 'LEISURE',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:7b04D0yLktCUpvxQBhmG7R'}],
#  'total': 23,
#  'limit': 50,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/artists?limit=50&offset=0&time_range=short_term',
#  'previous': None,
#  'next': None}

# %%
top_genres_and_artists = [[r['name'], r['id'], r['genres']] if len(r['genres']) > 0 else [r['name'], r['id'], ['unknown genre']] for r in results['items']]
top_genres_and_artists
# Out:
# [["L'Impératrice",
#   '4PwlsrN0t5mLN0C827cbEU',
#   ['french indie pop',
#    'french indietronica',
#    'french synthpop',
#    'indie soul',
#    'new french touch']],
#  ['Rhye',
#   '2AcUPzkVWo81vumdzeLLRN',
#   ['downtempo', 'indie soul', 'indietronica', 'shimmer pop']],
#  ['Fellini Félin',
#   '1FTFy5sAOlZpN6GY6s9VLh',
#   ['french indie pop', 'french indietronica', 'new french touch']],
#  ['Nahre Sol', '3YHAA3Ngue65DFIGVi0nqX', ['unknown genre']],
#  ['Kerala Dust',
#   '6lK8O3kyFThiTmgowQZGOH',
#   ['electronica', 'ethnotronica', 'organic electronic', 'organic house']],
#  ['Elder Island',
#   '3EnbnmqrrvApHJs6FMvYik',
#   ['electronica', 'indie soul', 'vapor soul']],
#  ['Maribou State',
#   '7zrkALJ9ayRjzysp4QYoEg',
#   ['electronica', 'future garage', 'indie soul']],
#  ['Weval',
#   '12tZvy2xFpWSkuJ3FsfisZ',
#   ['electronica',
#    'french indietronica',
#    'indie soul',
#    'microhouse',
#    'minimal techno']],
#  ['Kazy Lambist',
#   '41Ue54Vb6iWx2dcdRCM6oH',
#   ['french indie pop',
#    'french indietronica',
#    'indie soul',
#    'new french touch',
#    'tropical house']],
#  ['Joe Goddard',
#   '380fnmlGnkyueBMqGWx2k5',
#   ['alternative dance', 'electronica', 'indie soul', 'new rave', 'nu disco']],
#  ['Four Tet',
#   '7Eu1txygG6nJttLHbZdQOh',
#   ['alternative dance',
#    'electronica',
#    'folktronica',
#    'indie soul',
#    'intelligent dance music',
#    'new rave']],
#  ['DAVID AUGUST',
#   '1cS5EoXVqz7aON00AkVBBA',
#   ['deep disco house',
#    'deep euro house',
#    'electronica',
#    'hamburg electronic',
#    'microhouse',
#    'minimal techno',
#    'organic electronic',
#    'organic house',
#    'tech house']],
#  ['Pional',
#   '49mZfy9v5oNXAxp8FadWwI',
#   ['alternative dance',
#    'deep disco house',
#    'deep house',
#    'electronica',
#    'float house',
#    'indie soul',
#    'microhouse',
#    'nu disco',
#    'spanish electronic']],
#  ['Her',
#   '1T2WeXEi0XlZiPpjjDAY0L',
#   ['french indie pop',
#    'french indietronica',
#    'indie soul',
#    'new french touch',
#    'rennes indie']],
#  ['RY X', '2KjAo6wVc9d2WcxdxSArpV', ['indie folk', 'vapor soul']],
#  ['Caribou',
#   '4aEnNH9PuU1HF3TsZTru54',
#   ['alternative dance',
#    'chillwave',
#    'electronica',
#    'electropop',
#    'folktronica',
#    'indie rock',
#    'indie soul',
#    'indietronica',
#    'intelligent dance music',
#    'new rave']],
#  ['Romare',
#   '6d1HqiWNEKV9zFqQM9WeYo',
#   ['deep house',
#    'electronica',
#    'indie jazz',
#    'indie soul',
#    'ninja',
#    'nu jazz',
#    'soul',
#    'south african alternative']],
#  ['Crazy P',
#   '6jOz2B9qeID4dLP1o8bFGf',
#   ['alternative dance',
#    'deep house',
#    'disco',
#    'disco house',
#    'electronica',
#    'filter house',
#    'indie soul',
#    'nu disco',
#    'vocal house']],
#  ['DARKSIDE', '2933wDUojoQmvqSdTAE5NB', ['downtempo', 'electronica']],
#  ['MorMor',
#   '63vaeIIBKIe9zT91EORVbr',
#   ['canadian contemporary r&b', 'indie soul', 'vapor soul']],
#  ['Little Dragon',
#   '6Tyzp9KzpiZ04DABQoedps',
#   ['alternative dance',
#    'alternative r&b',
#    'art pop',
#    'chillwave',
#    'downtempo',
#    'electronica',
#    'electropop',
#    'escape room',
#    'gothenburg indie',
#    'indie soul',
#    'indietronica',
#    'new rave',
#    'swedish electropop',
#    'swedish synthpop',
#    'trip hop']],
#  ['HNNY',
#   '6Yae9Ia1nq6JLLojBzwN1r',
#   ['deep house',
#    'electronica',
#    'float house',
#    'indie jazz',
#    'indie soul',
#    'soul',
#    'swedish electronic',
#    'swedish house',
#    'swedish synthpop']],
#  ['LEISURE',
#   '7b04D0yLktCUpvxQBhmG7R',
#   ['auckland indie', 'electronica', 'indie soul', 'nu disco', 'vapor soul']]]

# %%
artists = []
for artist_name, artist_id, genres in top_genres_and_artists:
    if 'indie soul' in genres:
        artists.append([artist_name, artist_id])

# %%
artists
# Out:
# [["L'Impératrice", '4PwlsrN0t5mLN0C827cbEU'],
#  ['Rhye', '2AcUPzkVWo81vumdzeLLRN'],
#  ['Elder Island', '3EnbnmqrrvApHJs6FMvYik'],
#  ['Maribou State', '7zrkALJ9ayRjzysp4QYoEg'],
#  ['Weval', '12tZvy2xFpWSkuJ3FsfisZ'],
#  ['Kazy Lambist', '41Ue54Vb6iWx2dcdRCM6oH'],
#  ['Joe Goddard', '380fnmlGnkyueBMqGWx2k5'],
#  ['Four Tet', '7Eu1txygG6nJttLHbZdQOh'],
#  ['Pional', '49mZfy9v5oNXAxp8FadWwI'],
#  ['Her', '1T2WeXEi0XlZiPpjjDAY0L'],
#  ['Caribou', '4aEnNH9PuU1HF3TsZTru54'],
#  ['Romare', '6d1HqiWNEKV9zFqQM9WeYo'],
#  ['Crazy P', '6jOz2B9qeID4dLP1o8bFGf'],
#  ['MorMor', '63vaeIIBKIe9zT91EORVbr'],
#  ['Little Dragon', '6Tyzp9KzpiZ04DABQoedps'],
#  ['HNNY', '6Yae9Ia1nq6JLLojBzwN1r'],
#  ['LEISURE', '7b04D0yLktCUpvxQBhmG7R']]

# %%
def get_top_genres():
    results = sp.current_user_top_artists(time_range='short_term', limit=50)
    all_genres = [genre for r in results['items'] for genre in r['genres']]
    top_genres = Counter(all_genres)
    top_genres = {key : value for key, value in sorted(top_genres.items(), key=lambda k: k[1], reverse=True)}
    return top_genres

# %%
def get_top_artists(top_genres):
    # TO-DO: Let user select from top genres
    top_genre = list(top_genres.keys())[0] # Get the only one top genre for now
    print("Selected genre: %s" % (top_genre))
    artists = []
    for artist_name, artist_id, genres in top_genres_and_artists:
        if top_genre in genres:
            artists.append([artist_name, artist_id])
    print("Selected artists belonging to this genre: ", artists)
    return artists

# %%
def get_discography(artist_id, min_track_duration=30000):
    tracks = []
    album_ids = [album['id'] for album in sp.artist_albums(artist_id)['items'] if album['album_type'] != 'compilation' ]
    for album_id in album_ids:
        # track_ids = [track['id'] for track in sp.album_tracks(album_id)['items'] if track['duration_ms'] > min_track_duration]
        for track in sp.album_tracks(album_id)['items']:
            # There are unexpected results while retrieving the discography of an artist
            # Only get the albums that the artist owns
            flag = False
            for artist in track['artists']:
                if artist['id'] == artist_id:
                    flag = True
                    break
            if flag and track['duration_ms'] > min_track_duration:
                tracks.append(track['id'])
        if len(tracks) == 100:
            break
    return tracks

# %%
def get_all_features(artists):
    t = time.time()
    df = pd.DataFrame()
    for artist_name, artist_id in artists:
        try:
            tracks = get_discography(artist_id)
        except:
            time.sleep(2)
            tracks = get_discography(artist_id)
        
        while(len(tracks) > 0):
            if len(df) == 0:
                df = pd.DataFrame(sp.audio_features(tracks=tracks[:100]))
                df['artist_name'] = artist_name
                df['artist_id'] = artist_id
                # Could not add track names in here
                # API does not return audio features of all tracks
                # There might be a restriction on different markets
                # df['track_name'] = track_names[:100]
            else:
                df_feats = pd.DataFrame(sp.audio_features(tracks=tracks[:100]))
                df_feats['artist_name'] = artist_name
                df_feats['artist_id'] = artist_id
                # df_feats['track_name'] = track_names[:100]
                df = df.append(df_feats)
            tracks = tracks[100:]
    print(time.time() - t)    
    return df

# %%
def return_playlist(**kwargs):
    """
    danceability='default', energy='default', speechiness='default', 
                    acousticness='default', instrumentalness='default', liveness='default', 
                    valence='default', tempo='default'
    """
    
    # Select tracks based on the provided ranges
    top_genres = get_top_genres()
    artists = get_top_artists(top_genres)
    df = get_all_features(artists)
    print(len(df))
    # Sort dataframe based on provided features
    # Randomly return tracks based on sorted 
    # TO-DO: Select tracks based on user market
    for feature, value in kwargs.items():
        if value == 'high':
            df.sort_values(feature, ascending=False, inplace=True)
        elif value == 'low':
            df.sort_values(feature, ascending=True, inplace=True)
        df = df.head(len(df)//3)
    
    try:
        return df.sample(25)
    except:
        return df

# %%
playlist = return_playlist(danceability='low', instrumentalness='high')
# Out:
# Selected genre: indie soul
# Selected artists belonging to this genre:  [["L'Impératrice", '4PwlsrN0t5mLN0C827cbEU'], ['Rhye', '2AcUPzkVWo81vumdzeLLRN'], ['Elder Island', '3EnbnmqrrvApHJs6FMvYik'], ['Maribou State', '7zrkALJ9ayRjzysp4QYoEg'], ['Weval', '12tZvy2xFpWSkuJ3FsfisZ'], ['Kazy Lambist', '41Ue54Vb6iWx2dcdRCM6oH'], ['Joe Goddard', '380fnmlGnkyueBMqGWx2k5'], ['Four Tet', '7Eu1txygG6nJttLHbZdQOh'], ['Pional', '49mZfy9v5oNXAxp8FadWwI'], ['Her', '1T2WeXEi0XlZiPpjjDAY0L'], ['Caribou', '4aEnNH9PuU1HF3TsZTru54'], ['Romare', '6d1HqiWNEKV9zFqQM9WeYo'], ['Crazy P', '6jOz2B9qeID4dLP1o8bFGf'], ['MorMor', '63vaeIIBKIe9zT91EORVbr'], ['Little Dragon', '6Tyzp9KzpiZ04DABQoedps'], ['HNNY', '6Yae9Ia1nq6JLLojBzwN1r'], ['LEISURE', '7b04D0yLktCUpvxQBhmG7R']]
# 45.70816493034363
# 1633

# %%
playlist
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 16         0.326  0.0431    2   -21.172     1       0.0436      0.992000
# 35         0.643  0.4270    2   -11.478     0       0.0430      0.313000
# 24         0.610  0.5680    8    -8.949     0       0.0368      0.123000
# 48         0.463  0.8180    5    -9.534     0       0.0420      0.000249
# 37         0.379  0.5320   10   -21.419     1       0.4330      0.952000
# 36         0.239  0.0749    9    -8.847     0       0.0366      0.759000
# 38         0.419  0.1430    0   -18.906     1       0.0398      0.968000
# 28         0.297  0.2420    9   -22.504     1       0.0701      0.830000
# 47         0.388  0.7860    2    -8.542     1       0.0473      0.000006
# 12         0.415  0.1570    8   -20.237     1       0.0305      0.954000
# 22         0.314  0.4900    3    -8.251     0       0.0370      0.266000
# 7          0.493  0.8910    9    -9.203     1       0.0391      0.021100
# 50         0.505  0.7230   10    -9.086     0       0.0492      0.204000
# 30         0.561  0.5730    8   -10.104     0       0.0488      0.606000
# 18         0.443  0.4620   10    -9.069     1       0.0278      0.003920
# 60         0.458  0.9040    7    -7.906     1       0.0715      0.010000
# 43         0.411  0.4310    8   -18.776     1       0.0571      0.927000
# 15         0.325  0.0343    2   -23.749     1       0.0442      0.979000
# 46         0.637  0.8630    5    -9.562     1       0.0433      0.090800
# 43         0.226  0.0232    0   -30.835     1       0.0375      0.990000
# 32         0.267  0.6580    8    -9.576     1       0.0442      0.779000
# 19         0.226  0.0232    0   -30.835     1       0.0375      0.990000
# 39         0.563  0.6630    0    -7.819     1       0.0319      0.016500
# 56         0.593  0.6320    5   -10.175     0       0.0456      0.039000
# 26         0.393  0.3930   11   -14.891     1       0.0388      0.762000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 16             0.967    0.0991   0.0347  127.713  audio_features
# 35             0.870    0.1640   0.7070  117.965  audio_features
# 24             0.915    0.3830   0.3870   89.978  audio_features
# 48             0.820    0.1710   0.4040  138.965  audio_features
# 37             0.829    0.7000   0.3810  172.885  audio_features
# 36             0.924    0.0577   0.1750   74.477  audio_features
# 38             0.915    0.5550   0.1490  119.959  audio_features
# 28             0.949    0.1370   0.0359   58.911  audio_features
# 47             0.867    0.3630   0.8470  180.122  audio_features
# 12             0.838    0.1090   0.0376  107.643  audio_features
# 22             0.875    0.0599   0.1990   82.655  audio_features
# 7              0.926    0.2280   0.8450  150.012  audio_features
# 50             0.833    0.1060   0.2160  119.769  audio_features
# 30             0.854    0.2180   0.2430   81.979  audio_features
# 18             0.903    0.3260   0.3450   90.253  audio_features
# 60             0.844    0.1130   0.5310  100.931  audio_features
# 43             0.826    0.1080   0.5700   84.011  audio_features
# 15             0.941    0.0818   0.0684  128.177  audio_features
# 46             0.899    0.1150   0.1060  115.016  audio_features
# 43             0.899    0.0896   0.2760  115.317  audio_features
# 32             0.976    0.1570   0.1420   78.254  audio_features
# 19             0.899    0.0896   0.2760  115.317  audio_features
# 39             0.840    0.1160   0.3110  180.162  audio_features
# 56             0.830    0.4130   0.1520  111.009  audio_features
# 26             0.866    0.1070   0.0391  128.004  audio_features
#
#                         id                                   uri  \
# 16  0O8UJs2QAtV5HetSC0hOlK  spotify:track:0O8UJs2QAtV5HetSC0hOlK
# 35  4nYnaFmUdoBvNVhs5Wv6uo  spotify:track:4nYnaFmUdoBvNVhs5Wv6uo
# 24  61Pn3XjC98UkrmCWTjbmPd  spotify:track:61Pn3XjC98UkrmCWTjbmPd
# 48  6bi6dD2jAxvOta3DsPxavl  spotify:track:6bi6dD2jAxvOta3DsPxavl
# 37  6MU27O5Ob87QrVXtkuZd4C  spotify:track:6MU27O5Ob87QrVXtkuZd4C
# 36  5VNb023MigZZTLoq4xRGXd  spotify:track:5VNb023MigZZTLoq4xRGXd
# 38  29t45l3TU4wYULHGBWJWcv  spotify:track:29t45l3TU4wYULHGBWJWcv
# 28  5rOa9i42OB6ZXiceC2cZ8b  spotify:track:5rOa9i42OB6ZXiceC2cZ8b
# 47  6eRliYsJm7QHBQ9tF9uviS  spotify:track:6eRliYsJm7QHBQ9tF9uviS
# 12  6qyyfmZLksKpM3n4CwZWTC  spotify:track:6qyyfmZLksKpM3n4CwZWTC
# 22  6RavOGeNW1TARKj5xXswAt  spotify:track:6RavOGeNW1TARKj5xXswAt
# 7   61ifNM1pfvogeND9XXR9tW  spotify:track:61ifNM1pfvogeND9XXR9tW
# 50  7whBvgIWaitYehr6KSQun1  spotify:track:7whBvgIWaitYehr6KSQun1
# 30  2XRRV8LElpRWMWuxwlnQDL  spotify:track:2XRRV8LElpRWMWuxwlnQDL
# 18  5YVUe1lATzbHABrqYYflkd  spotify:track:5YVUe1lATzbHABrqYYflkd
# 60  454MLi0EXJbE5A4p53cXxh  spotify:track:454MLi0EXJbE5A4p53cXxh
# 43  4ETHz3Agd4QAYMbdBFpgGQ  spotify:track:4ETHz3Agd4QAYMbdBFpgGQ
# 15  4BZmUSWrHiop8R8RRH0olL  spotify:track:4BZmUSWrHiop8R8RRH0olL
# 46  38esMXs9IEanExOGg8WICw  spotify:track:38esMXs9IEanExOGg8WICw
# 43  4LuzaLW3fjO145uDeqQ4jb  spotify:track:4LuzaLW3fjO145uDeqQ4jb
# 32  4mvJmwc6cqgukLoGrNEI21  spotify:track:4mvJmwc6cqgukLoGrNEI21
# 19  6c2JrcBmzNIzyMPKv6mwDD  spotify:track:6c2JrcBmzNIzyMPKv6mwDD
# 39  2qt2fVnHPI84dKsSVG8QDy  spotify:track:2qt2fVnHPI84dKsSVG8QDy
# 56  2riGfIdTac01gA3eDJimm2  spotify:track:2riGfIdTac01gA3eDJimm2
# 26  0QIyJvZOkzMFLJb6mTLFUM  spotify:track:0QIyJvZOkzMFLJb6mTLFUM
#
#                                            track_href  \
# 16  https://api.spotify.com/v1/tracks/0O8UJs2QAtV5...
# 35  https://api.spotify.com/v1/tracks/4nYnaFmUdoBv...
# 24  https://api.spotify.com/v1/tracks/61Pn3XjC98Uk...
# 48  https://api.spotify.com/v1/tracks/6bi6dD2jAxvO...
# 37  https://api.spotify.com/v1/tracks/6MU27O5Ob87Q...
# 36  https://api.spotify.com/v1/tracks/5VNb023MigZZ...
# 38  https://api.spotify.com/v1/tracks/29t45l3TU4wY...
# 28  https://api.spotify.com/v1/tracks/5rOa9i42OB6Z...
# 47  https://api.spotify.com/v1/tracks/6eRliYsJm7QH...
# 12  https://api.spotify.com/v1/tracks/6qyyfmZLksKp...
# 22  https://api.spotify.com/v1/tracks/6RavOGeNW1TA...
# 7   https://api.spotify.com/v1/tracks/61ifNM1pfvog...
# 50  https://api.spotify.com/v1/tracks/7whBvgIWaitY...
# 30  https://api.spotify.com/v1/tracks/2XRRV8LElpRW...
# 18  https://api.spotify.com/v1/tracks/5YVUe1lATzbH...
# 60  https://api.spotify.com/v1/tracks/454MLi0EXJbE...
# 43  https://api.spotify.com/v1/tracks/4ETHz3Agd4QA...
# 15  https://api.spotify.com/v1/tracks/4BZmUSWrHiop...
# 46  https://api.spotify.com/v1/tracks/38esMXs9IEan...
# 43  https://api.spotify.com/v1/tracks/4LuzaLW3fjO1...
# 32  https://api.spotify.com/v1/tracks/4mvJmwc6cqgu...
# 19  https://api.spotify.com/v1/tracks/6c2JrcBmzNIz...
# 39  https://api.spotify.com/v1/tracks/2qt2fVnHPI84...
# 56  https://api.spotify.com/v1/tracks/2riGfIdTac01...
# 26  https://api.spotify.com/v1/tracks/0QIyJvZOkzMF...
#
#                                          analysis_url  duration_ms  \
# 16  https://api.spotify.com/v1/audio-analysis/0O8U...        81781
# 35  https://api.spotify.com/v1/audio-analysis/4nYn...        40693
# 24  https://api.spotify.com/v1/audio-analysis/61Pn...       302227
# 48  https://api.spotify.com/v1/audio-analysis/6bi6...       236000
# 37  https://api.spotify.com/v1/audio-analysis/6MU2...       101693
# 36  https://api.spotify.com/v1/audio-analysis/5VNb...        62165
# 38  https://api.spotify.com/v1/audio-analysis/29t4...       184063
# 28  https://api.spotify.com/v1/audio-analysis/5rOa...        99467
# 47  https://api.spotify.com/v1/audio-analysis/6eRl...        61037
# 12  https://api.spotify.com/v1/audio-analysis/6qyy...       138813
# 22  https://api.spotify.com/v1/audio-analysis/6Rav...       309707
# 7   https://api.spotify.com/v1/audio-analysis/61if...        60799
# 50  https://api.spotify.com/v1/audio-analysis/7whB...       232747
# 30  https://api.spotify.com/v1/audio-analysis/2XRR...       268028
# 18  https://api.spotify.com/v1/audio-analysis/5YVU...        61013
# 60  https://api.spotify.com/v1/audio-analysis/454M...       313823
# 43  https://api.spotify.com/v1/audio-analysis/4ETH...       224400
# 15  https://api.spotify.com/v1/audio-analysis/4BZm...       264208
# 46  https://api.spotify.com/v1/audio-analysis/38es...       505067
# 43  https://api.spotify.com/v1/audio-analysis/4Luz...        53253
# 32  https://api.spotify.com/v1/audio-analysis/4mvJ...       126467
# 19  https://api.spotify.com/v1/audio-analysis/6c2J...        53253
# 39  https://api.spotify.com/v1/audio-analysis/2qt2...       290788
# 56  https://api.spotify.com/v1/audio-analysis/2riG...       322000
# 26  https://api.spotify.com/v1/audio-analysis/0QIy...       197904
#
#     time_signature    artist_name               artist_id
# 16               3       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 35               4   Kazy Lambist  41Ue54Vb6iWx2dcdRCM6oH
# 24               4       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 48               4         Pional  49mZfy9v5oNXAxp8FadWwI
# 37               4       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 36               1        LEISURE  7b04D0yLktCUpvxQBhmG7R
# 38               4         Romare  6d1HqiWNEKV9zFqQM9WeYo
# 28               5       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 47               4        LEISURE  7b04D0yLktCUpvxQBhmG7R
# 12               4           Rhye  2AcUPzkVWo81vumdzeLLRN
# 22               4       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 7                4        LEISURE  7b04D0yLktCUpvxQBhmG7R
# 50               4        Caribou  4aEnNH9PuU1HF3TsZTru54
# 30               4  Maribou State  7zrkALJ9ayRjzysp4QYoEg
# 18               4        LEISURE  7b04D0yLktCUpvxQBhmG7R
# 60               4       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 43               3       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 15               4       Four Tet  7Eu1txygG6nJttLHbZdQOh
# 46               4         Pional  49mZfy9v5oNXAxp8FadWwI
# 43               4        Caribou  4aEnNH9PuU1HF3TsZTru54
# 32               4        Caribou  4aEnNH9PuU1HF3TsZTru54
# 19               4        Caribou  4aEnNH9PuU1HF3TsZTru54
# 39               4         Pional  49mZfy9v5oNXAxp8FadWwI
# 56               4          Weval  12tZvy2xFpWSkuJ3FsfisZ
# 26               4       Four Tet  7Eu1txygG6nJttLHbZdQOh

# %%
def get_playlist_tracks(playlist):
    track_uris = playlist['uri'].to_list()
    artist_names = playlist['artist_name'].to_list()
    track_names = [track['name'] for track in sp.tracks(track_uris)['tracks']]
    tracks = ["{} by {}".format(track, artist) for track, artist in zip(track_names, artist_names)]
    return tracks, track_uris

# %%
_, ids = get_playlist_tracks(playlist)

# %%
ids
# Out:
# ['spotify:track:0O8UJs2QAtV5HetSC0hOlK',
#  'spotify:track:4nYnaFmUdoBvNVhs5Wv6uo',
#  'spotify:track:61Pn3XjC98UkrmCWTjbmPd',
#  'spotify:track:6bi6dD2jAxvOta3DsPxavl',
#  'spotify:track:6MU27O5Ob87QrVXtkuZd4C',
#  'spotify:track:5VNb023MigZZTLoq4xRGXd',
#  'spotify:track:29t45l3TU4wYULHGBWJWcv',
#  'spotify:track:5rOa9i42OB6ZXiceC2cZ8b',
#  'spotify:track:6eRliYsJm7QHBQ9tF9uviS',
#  'spotify:track:6qyyfmZLksKpM3n4CwZWTC',
#  'spotify:track:6RavOGeNW1TARKj5xXswAt',
#  'spotify:track:61ifNM1pfvogeND9XXR9tW',
#  'spotify:track:7whBvgIWaitYehr6KSQun1',
#  'spotify:track:2XRRV8LElpRWMWuxwlnQDL',
#  'spotify:track:5YVUe1lATzbHABrqYYflkd',
#  'spotify:track:454MLi0EXJbE5A4p53cXxh',
#  'spotify:track:4ETHz3Agd4QAYMbdBFpgGQ',
#  'spotify:track:4BZmUSWrHiop8R8RRH0olL',
#  'spotify:track:38esMXs9IEanExOGg8WICw',
#  'spotify:track:4LuzaLW3fjO145uDeqQ4jb',
#  'spotify:track:4mvJmwc6cqgukLoGrNEI21',
#  'spotify:track:6c2JrcBmzNIzyMPKv6mwDD',
#  'spotify:track:2qt2fVnHPI84dKsSVG8QDy',
#  'spotify:track:2riGfIdTac01gA3eDJimm2',
#  'spotify:track:0QIyJvZOkzMFLJb6mTLFUM']

# %%
string = ""
for i in ids:
    string += i
    string += " "
string
# Out:
# 'spotify:track:0O8UJs2QAtV5HetSC0hOlK spotify:track:4nYnaFmUdoBvNVhs5Wv6uo spotify:track:61Pn3XjC98UkrmCWTjbmPd spotify:track:6bi6dD2jAxvOta3DsPxavl spotify:track:6MU27O5Ob87QrVXtkuZd4C spotify:track:5VNb023MigZZTLoq4xRGXd spotify:track:29t45l3TU4wYULHGBWJWcv spotify:track:5rOa9i42OB6ZXiceC2cZ8b spotify:track:6eRliYsJm7QHBQ9tF9uviS spotify:track:6qyyfmZLksKpM3n4CwZWTC spotify:track:6RavOGeNW1TARKj5xXswAt spotify:track:61ifNM1pfvogeND9XXR9tW spotify:track:7whBvgIWaitYehr6KSQun1 spotify:track:2XRRV8LElpRWMWuxwlnQDL spotify:track:5YVUe1lATzbHABrqYYflkd spotify:track:454MLi0EXJbE5A4p53cXxh spotify:track:4ETHz3Agd4QAYMbdBFpgGQ spotify:track:4BZmUSWrHiop8R8RRH0olL spotify:track:38esMXs9IEanExOGg8WICw spotify:track:4LuzaLW3fjO145uDeqQ4jb spotify:track:4mvJmwc6cqgukLoGrNEI21 spotify:track:6c2JrcBmzNIzyMPKv6mwDD spotify:track:2qt2fVnHPI84dKsSVG8QDy spotify:track:2riGfIdTac01gA3eDJimm2 spotify:track:0QIyJvZOkzMFLJb6mTLFUM '

# %%
string[:-1].split(" ")
# Out:
# ['spotify:track:0O8UJs2QAtV5HetSC0hOlK',
#  'spotify:track:4nYnaFmUdoBvNVhs5Wv6uo',
#  'spotify:track:61Pn3XjC98UkrmCWTjbmPd',
#  'spotify:track:6bi6dD2jAxvOta3DsPxavl',
#  'spotify:track:6MU27O5Ob87QrVXtkuZd4C',
#  'spotify:track:5VNb023MigZZTLoq4xRGXd',
#  'spotify:track:29t45l3TU4wYULHGBWJWcv',
#  'spotify:track:5rOa9i42OB6ZXiceC2cZ8b',
#  'spotify:track:6eRliYsJm7QHBQ9tF9uviS',
#  'spotify:track:6qyyfmZLksKpM3n4CwZWTC',
#  'spotify:track:6RavOGeNW1TARKj5xXswAt',
#  'spotify:track:61ifNM1pfvogeND9XXR9tW',
#  'spotify:track:7whBvgIWaitYehr6KSQun1',
#  'spotify:track:2XRRV8LElpRWMWuxwlnQDL',
#  'spotify:track:5YVUe1lATzbHABrqYYflkd',
#  'spotify:track:454MLi0EXJbE5A4p53cXxh',
#  'spotify:track:4ETHz3Agd4QAYMbdBFpgGQ',
#  'spotify:track:4BZmUSWrHiop8R8RRH0olL',
#  'spotify:track:38esMXs9IEanExOGg8WICw',
#  'spotify:track:4LuzaLW3fjO145uDeqQ4jb',
#  'spotify:track:4mvJmwc6cqgukLoGrNEI21',
#  'spotify:track:6c2JrcBmzNIzyMPKv6mwDD',
#  'spotify:track:2qt2fVnHPI84dKsSVG8QDy',
#  'spotify:track:2riGfIdTac01gA3eDJimm2',
#  'spotify:track:0QIyJvZOkzMFLJb6mTLFUM']
